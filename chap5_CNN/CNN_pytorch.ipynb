# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels= 1 ,  
                out_channels= 32 ,
                kernel_size= 7 ,
                stride= 1 ,
                padding= 3 ,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(
                in_channels= 32 ,
                out_channels= 64 ,
                kernel_size= 5 ,
                stride= 1 ,
                padding= 2 ,
            ),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size= 2)
         

        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view( x.size(0), -1 )  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# 100%|██████████| 9.91M/9.91M [05:26<00:00, 30.4kB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 102kB/s]
# 100%|██████████| 1.65M/1.65M [00:39<00:00, 42.1kB/s]
# 100%|██████████| 4.54k/4.54k [00:00<?, ?B/s]
# d:\anaconda3\Lib\site-packages\torchvision\datasets\mnist.py:81: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\袁立勋\AppData\Local\Temp\ipykernel_19628\3248930981.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# d:\anaconda3\Lib\site-packages\torchvision\datasets\mnist.py:71: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# C:\Users\袁立勋\AppData\Local\Temp\ipykernel_19628\3248930981.py:74: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(out2)
# ========== 20 ===== ===== test accuracy is  0.4 ==========
# ========== 40 ===== ===== test accuracy is  0.316 ==========
# ========== 60 ===== ===== test accuracy is  0.49 ==========
# ========== 80 ===== ===== test accuracy is  0.56 ==========
# ========== 100 ===== ===== test accuracy is  0.638 ==========
# ========== 120 ===== ===== test accuracy is  0.708 ==========
# ========== 140 ===== ===== test accuracy is  0.726 ==========
# ========== 160 ===== ===== test accuracy is  0.776 ==========
# ========== 180 ===== ===== test accuracy is  0.806 ==========
# ========== 200 ===== ===== test accuracy is  0.818 ==========
# ========== 220 ===== ===== test accuracy is  0.83 ==========
# ========== 240 ===== ===== test accuracy is  0.85 ==========
# ========== 260 ===== ===== test accuracy is  0.868 ==========
# ========== 280 ===== ===== test accuracy is  0.888 ==========
# ========== 300 ===== ===== test accuracy is  0.862 ==========
# ========== 320 ===== ===== test accuracy is  0.86 ==========
# ========== 340 ===== ===== test accuracy is  0.876 ==========
# ========== 360 ===== ===== test accuracy is  0.888 ==========
# ========== 380 ===== ===== test accuracy is  0.892 ==========
# ========== 400 ===== ===== test accuracy is  0.896 ==========
# ========== 420 ===== ===== test accuracy is  0.892 ==========
# ========== 440 ===== ===== test accuracy is  0.902 ==========
# ========== 460 ===== ===== test accuracy is  0.906 ==========
# ========== 480 ===== ===== test accuracy is  0.906 ==========
# ========== 500 ===== ===== test accuracy is  0.902 ==========
# ========== 520 ===== ===== test accuracy is  0.888 ==========
# ========== 540 ===== ===== test accuracy is  0.91 ==========
# ========== 560 ===== ===== test accuracy is  0.912 ==========
# ========== 580 ===== ===== test accuracy is  0.926 ==========
# ========== 600 ===== ===== test accuracy is  0.924 ==========
# ========== 620 ===== ===== test accuracy is  0.936 ==========
# ========== 640 ===== ===== test accuracy is  0.934 ==========
# ========== 660 ===== ===== test accuracy is  0.922 ==========
# ========== 680 ===== ===== test accuracy is  0.922 ==========
# ========== 700 ===== ===== test accuracy is  0.922 ==========
# ========== 720 ===== ===== test accuracy is  0.92 ==========
# ========== 740 ===== ===== test accuracy is  0.93 ==========
# ========== 760 ===== ===== test accuracy is  0.938 ==========
# ========== 780 ===== ===== test accuracy is  0.93 ==========
# ========== 800 ===== ===== test accuracy is  0.93 ==========
# ========== 820 ===== ===== test accuracy is  0.944 ==========
# ========== 840 ===== ===== test accuracy is  0.944 ==========
# ========== 860 ===== ===== test accuracy is  0.936 ==========
# ========== 880 ===== ===== test accuracy is  0.93 ==========
# ========== 900 ===== ===== test accuracy is  0.938 ==========
# ========== 920 ===== ===== test accuracy is  0.95 ==========
# ========== 940 ===== ===== test accuracy is  0.944 ==========
# ========== 960 ===== ===== test accuracy is  0.944 ==========
# ========== 980 ===== ===== test accuracy is  0.952 ==========
# ========== 1000 ===== ===== test accuracy is  0.95 ==========
# ========== 1020 ===== ===== test accuracy is  0.94 ==========
# ========== 1040 ===== ===== test accuracy is  0.952 ==========
# ========== 1060 ===== ===== test accuracy is  0.934 ==========
# ========== 1080 ===== ===== test accuracy is  0.95 ==========
# ========== 1100 ===== ===== test accuracy is  0.946 ==========
# ========== 1120 ===== ===== test accuracy is  0.948 ==========
# ========== 1140 ===== ===== test accuracy is  0.948 ==========
# ========== 1160 ===== ===== test accuracy is  0.946 ==========
# ========== 1180 ===== ===== test accuracy is  0.958 ==========
# ========== 20 ===== ===== test accuracy is  0.946 ==========
# ========== 40 ===== ===== test accuracy is  0.956 ==========
# ========== 60 ===== ===== test accuracy is  0.952 ==========
# ========== 80 ===== ===== test accuracy is  0.96 ==========
# ========== 100 ===== ===== test accuracy is  0.952 ==========
# ========== 120 ===== ===== test accuracy is  0.954 ==========
# ========== 140 ===== ===== test accuracy is  0.96 ==========
# ========== 160 ===== ===== test accuracy is  0.948 ==========
# ========== 180 ===== ===== test accuracy is  0.956 ==========
# ========== 200 ===== ===== test accuracy is  0.964 ==========
# ========== 220 ===== ===== test accuracy is  0.96 ==========
# ========== 240 ===== ===== test accuracy is  0.952 ==========
# ========== 260 ===== ===== test accuracy is  0.958 ==========
# ========== 280 ===== ===== test accuracy is  0.962 ==========
# ========== 300 ===== ===== test accuracy is  0.95 ==========
# ========== 320 ===== ===== test accuracy is  0.956 ==========
# ========== 340 ===== ===== test accuracy is  0.954 ==========
# ========== 360 ===== ===== test accuracy is  0.96 ==========
# ========== 380 ===== ===== test accuracy is  0.96 ==========
# ========== 400 ===== ===== test accuracy is  0.968 ==========
# ========== 420 ===== ===== test accuracy is  0.956 ==========
# ========== 440 ===== ===== test accuracy is  0.962 ==========
# ========== 460 ===== ===== test accuracy is  0.954 ==========
# ========== 480 ===== ===== test accuracy is  0.974 ==========
# ========== 500 ===== ===== test accuracy is  0.958 ==========
# ========== 520 ===== ===== test accuracy is  0.966 ==========
# ========== 540 ===== ===== test accuracy is  0.966 ==========
# ========== 560 ===== ===== test accuracy is  0.96 ==========
# ========== 580 ===== ===== test accuracy is  0.962 ==========
# ========== 600 ===== ===== test accuracy is  0.946 ==========
# ========== 620 ===== ===== test accuracy is  0.972 ==========
# ========== 640 ===== ===== test accuracy is  0.962 ==========
# ========== 660 ===== ===== test accuracy is  0.958 ==========
# ========== 680 ===== ===== test accuracy is  0.956 ==========
# ========== 700 ===== ===== test accuracy is  0.97 ==========
# ========== 720 ===== ===== test accuracy is  0.962 ==========
# ========== 740 ===== ===== test accuracy is  0.96 ==========
# ========== 760 ===== ===== test accuracy is  0.972 ==========
# ========== 780 ===== ===== test accuracy is  0.958 ==========
# ========== 800 ===== ===== test accuracy is  0.964 ==========
# ========== 820 ===== ===== test accuracy is  0.956 ==========
# ========== 840 ===== ===== test accuracy is  0.964 ==========
# ========== 860 ===== ===== test accuracy is  0.966 ==========
# ========== 880 ===== ===== test accuracy is  0.976 ==========
# ========== 900 ===== ===== test accuracy is  0.972 ==========
# ========== 920 ===== ===== test accuracy is  0.962 ==========
# ========== 940 ===== ===== test accuracy is  0.972 ==========
# ========== 960 ===== ===== test accuracy is  0.972 ==========
# ========== 980 ===== ===== test accuracy is  0.962 ==========
# ========== 1000 ===== ===== test accuracy is  0.952 ==========
# ========== 1020 ===== ===== test accuracy is  0.956 ==========
# ========== 1040 ===== ===== test accuracy is  0.976 ==========
# ========== 1060 ===== ===== test accuracy is  0.968 ==========
# ========== 1080 ===== ===== test accuracy is  0.97 ==========
# ========== 1100 ===== ===== test accuracy is  0.972 ==========
# ========== 1120 ===== ===== test accuracy is  0.974 ==========
# ========== 1140 ===== ===== test accuracy is  0.97 ==========
# ========== 1160 ===== ===== test accuracy is  0.968 ==========
# ========== 1180 ===== ===== test accuracy is  0.966 ==========
# ========== 20 ===== ===== test accuracy is  0.966 ==========
# ========== 40 ===== ===== test accuracy is  0.97 ==========
# ========== 60 ===== ===== test accuracy is  0.974 ==========
# ========== 80 ===== ===== test accuracy is  0.974 ==========
# ========== 100 ===== ===== test accuracy is  0.962 ==========
# ========== 120 ===== ===== test accuracy is  0.972 ==========
# ========== 140 ===== ===== test accuracy is  0.966 ==========
# ========== 160 ===== ===== test accuracy is  0.96 ==========
# ========== 180 ===== ===== test accuracy is  0.972 ==========
# ========== 200 ===== ===== test accuracy is  0.974 ==========
# ========== 220 ===== ===== test accuracy is  0.976 ==========
# ========== 240 ===== ===== test accuracy is  0.976 ==========
# ========== 260 ===== ===== test accuracy is  0.976 ==========
# ========== 280 ===== ===== test accuracy is  0.972 ==========
# ========== 300 ===== ===== test accuracy is  0.976 ==========
# ========== 320 ===== ===== test accuracy is  0.964 ==========
# ========== 340 ===== ===== test accuracy is  0.976 ==========
# ========== 360 ===== ===== test accuracy is  0.968 ==========
# ========== 380 ===== ===== test accuracy is  0.976 ==========
# ========== 400 ===== ===== test accuracy is  0.976 ==========
# ========== 420 ===== ===== test accuracy is  0.986 ==========
# ========== 440 ===== ===== test accuracy is  0.986 ==========
# ========== 460 ===== ===== test accuracy is  0.97 ==========
# ========== 480 ===== ===== test accuracy is  0.97 ==========
# ========== 500 ===== ===== test accuracy is  0.976 ==========
# ========== 520 ===== ===== test accuracy is  0.97 ==========
# ========== 540 ===== ===== test accuracy is  0.98 ==========
# ========== 560 ===== ===== test accuracy is  0.976 ==========
# ========== 580 ===== ===== test accuracy is  0.972 ==========
# ========== 600 ===== ===== test accuracy is  0.972 ==========
# ========== 620 ===== ===== test accuracy is  0.972 ==========
# ========== 640 ===== ===== test accuracy is  0.972 ==========
# ========== 660 ===== ===== test accuracy is  0.974 ==========
# ========== 680 ===== ===== test accuracy is  0.976 ==========
# ========== 700 ===== ===== test accuracy is  0.976 ==========
# ========== 720 ===== ===== test accuracy is  0.978 ==========
# ========== 740 ===== ===== test accuracy is  0.976 ==========
# ========== 760 ===== ===== test accuracy is  0.976 ==========
# ========== 780 ===== ===== test accuracy is  0.97 ==========
# ========== 800 ===== ===== test accuracy is  0.964 ==========
# ========== 820 ===== ===== test accuracy is  0.97 ==========
# ========== 840 ===== ===== test accuracy is  0.982 ==========
# ========== 860 ===== ===== test accuracy is  0.976 ==========
# ========== 880 ===== ===== test accuracy is  0.974 ==========
# ========== 900 ===== ===== test accuracy is  0.972 ==========
# ========== 920 ===== ===== test accuracy is  0.97 ==========
# ========== 940 ===== ===== test accuracy is  0.972 ==========
# ========== 960 ===== ===== test accuracy is  0.974 ==========
# ========== 980 ===== ===== test accuracy is  0.976 ==========
# ========== 1000 ===== ===== test accuracy is  0.982 ==========
# ========== 1020 ===== ===== test accuracy is  0.97 ==========
# ========== 1040 ===== ===== test accuracy is  0.978 ==========
# ========== 1060 ===== ===== test accuracy is  0.982 ==========
# ========== 1080 ===== ===== test accuracy is  0.98 ==========
# ========== 1100 ===== ===== test accuracy is  0.974 ==========
# ========== 1120 ===== ===== test accuracy is  0.98 ==========
# ========== 1140 ===== ===== test accuracy is  0.98 ==========
# ========== 1160 ===== ===== test accuracy is  0.98 ==========
# ========== 1180 ===== ===== test accuracy is  0.982 ==========
