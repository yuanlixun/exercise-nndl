# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# 创建模型
cnn_model = models.Sequential([
    layers.Conv2D(32, (7, 7), activation='relu', padding='same', input_shape=(28, 28, 1)),  # 第一层卷积
    layers.MaxPooling2D(pool_size=(2, 2)),  # 池化层
    layers.Conv2D(64, (5, 5), activation='relu', padding='same'),  # 第二层卷积
    layers.MaxPooling2D(pool_size=(2, 2)),  # 池化层
    layers.Flatten(),  # 将二维数据展平为一维
    layers.Dense(1024, activation='relu'),  # 全连接层
    layers.Dropout(0.3),  # Dropout 层
    layers.Dense(10, activation='softmax')  # 输出层
])

# 编译模型
cnn_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

# 加载 MNIST 数据集
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

# 数据归一化并添加通道维度
train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0
train_images = train_images[..., tf.newaxis]  # 添加通道维度
test_images = test_images[..., tf.newaxis]

# 训练模型
cnn_model.fit(train_images, train_labels, epochs=5, batch_size=100, validation_split=0.1)

# 评估模型
loss, accuracy = cnn_model.evaluate(test_images, test_labels)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Epoch 1/5
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 18s 30ms/step - accuracy: 0.8895 - loss: 0.4086 - val_accuracy: 0.9687 - val_loss: 0.1104
# Epoch 2/5
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9682 - loss: 0.1088 - val_accuracy: 0.9820 - val_loss: 0.0663
# Epoch 3/5
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9780 - loss: 0.0727 - val_accuracy: 0.9850 - val_loss: 0.0527
# Epoch 4/5
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 16s 29ms/step - accuracy: 0.9828 - loss: 0.0550 - val_accuracy: 0.9847 - val_loss: 0.0515
# Epoch 5/5
# 540/540 ━━━━━━━━━━━━━━━━━━━━ 16s 30ms/step - accuracy: 0.9858 - loss: 0.0460 - val_accuracy: 0.9890 - val_loss: 0.0420
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9879 - loss: 0.0348
# Test Accuracy: 0.9879
